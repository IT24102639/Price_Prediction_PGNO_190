# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Out:
# Mounted at /content/drive

# %%
# Load previous
data_path = '/content/drive/My Drive/PGNO-190/preprocessed_after_IT24102639.csv'
df = pd.read_csv(data_path)



# Drop irrelevant
irrelevant_cols = ['img_link', 'product_link', 'user_id', 'review_id']
df = df.drop(columns=irrelevant_cols, errors='ignore')

# EDA: Pairplot
sns.pairplot(df[['discounted_price', 'actual_price', 'rating']])
plt.suptitle('Pairplot of Selected Features')
plt.savefig('/content/eda_pairplot.png')
plt.show()



# Save
save_path = '/content/drive/My Drive/PGNO-190/preprocessed_after_IT24102676.csv'
df.to_csv(save_path, index=False)
